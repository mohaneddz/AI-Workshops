# %% [markdown]
# <img src="https://res.cloudinary.com/dtizipxds/image/upload/q_auto/f_auto/v1776264397/banner_yvwajv.png" width="100%">

# %%
# %pip install numpy pandas matplotlib seaborn scikit-learn

# %% [markdown]
# # Exercise - Anomaly Detection
# Use `train.csv` and `test.csv` to detect suspicious transactions.

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor

sns.set_theme(style="whitegrid")
train_df = pd.read_csv(Path("train.csv"))
test_df = pd.read_csv(Path("test.csv"))
print(train_df.shape, test_df.shape)

# %% [markdown]
# ## 1) Select feature columns

# %%
# TODO: select numeric modeling columns (hint: V-columns + amount)
feature_cols = ...
X_train = train_df[feature_cols].copy()
X_test = test_df[feature_cols].copy()

# %% [markdown]
# ## 2) Fit scaler and transform data

# %%
# TODO: scale train and test features
scaler = ...
X_train_scaled = ...
X_test_scaled = ...

# %% [markdown]
# ## 3) Z-score anomalies

# %%
# TODO: compute z-score flags on test set (threshold=3)
z = ...
z_flag = ...
print("z-score anomalies:", int(z_flag.sum()))

# %% [markdown]
# ## 4) Isolation Forest anomalies

# %%
# TODO: fit isolation forest and predict anomalies on test
iso = ...
iso_flag = ...
print("Isolation Forest anomalies:", int(iso_flag.sum()))

# %% [markdown]
# ## 5) LOF anomalies

# %%
# TODO: fit LOF directly on test scaled data
lof = ...
lof_flag = ...
print("LOF anomalies:", int(lof_flag.sum()))

# %% [markdown]
# ## 6) Visualize

# %%
plot_df = test_df[["time_s", "amount"]].copy()
plot_df["isolation_forest"] = iso_flag

plt.figure(figsize=(9,5))
sns.scatterplot(data=plot_df.sample(n=min(2000, len(plot_df)), random_state=42), x="time_s", y="amount", hue="isolation_forest", s=25, alpha=0.8)
plt.title("Detected anomalies (Isolation Forest)")
plt.tight_layout()
plt.show()
