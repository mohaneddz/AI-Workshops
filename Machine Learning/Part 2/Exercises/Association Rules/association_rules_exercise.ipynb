# %% [markdown]
# <img src="https://res.cloudinary.com/dtizipxds/image/upload/q_auto/f_auto/v1776264397/banner_yvwajv.png" width="100%">

# %%
# %pip install numpy pandas matplotlib seaborn mlxtend

# %% [markdown]
# # Exercise - Association Rules
# Mine shopping patterns from transaction data.

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, fpgrowth, association_rules

sns.set_theme(style="whitegrid")
train_df = pd.read_csv(Path("train.csv"))
test_df = pd.read_csv(Path("test.csv"))
print(train_df.shape, test_df.shape)

# %% [markdown]
# ## 1) Convert train transactions to basket matrix

# %%
# TODO: group by transaction_id and build basket matrix with TransactionEncoder
transactions = ...
te = ...
te_ary = ...
basket = ...
basket.head()

# %% [markdown]
# ## 2) Apriori and FP-Growth

# %%
# TODO: run Apriori + FP-Growth with min_support=0.015
ap_itemsets = ...
fp_itemsets = ...

# TODO: convert itemsets to rules (confidence >= 0.15)
ap_rules = ...
fp_rules = ...

ap_rules[["antecedents", "consequents", "support", "confidence", "lift"]].head()

# %% [markdown]
# ## 3) ECLAT (simple version)

# %%
# TODO: complete custom ECLAT helper (same logic as template)
def build_tidsets(basket_df):
    tidsets = {}
    for col in basket_df.columns:
        idx = set(basket_df.index[basket_df[col]].tolist())
        if idx:
            tidsets[frozenset([col])] = idx
    return tidsets

# TODO: fill recursive mining and wrapper

def eclat(basket_df, min_support=0.015):
    ...

eclat_itemsets = eclat(basket)
eclat_itemsets.head()
