# %% [markdown]
# <img src="https://res.cloudinary.com/dtizipxds/image/upload/q_auto/f_auto/v1776264397/banner_yvwajv.png" width="100%">

# %%
# %pip install numpy pandas matplotlib seaborn scikit-learn umap-learn

# %% [markdown]
# # Exercise - Dimensionality Reduction
# Use PCA, t-SNE, and UMAP to create 2D embeddings.

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import umap.umap_ as umap

sns.set_theme(style="whitegrid")
train_df = pd.read_csv(Path("train.csv"))
test_df = pd.read_csv(Path("test.csv"))
print(train_df.shape, test_df.shape)

# %% [markdown]
# ## 1) Prepare matrix

# %%
# TODO: choose numeric features and standardize
feature_cols = ...
X_train = train_df[feature_cols]
X_test = test_df[feature_cols]

scaler = ...
X_train_scaled = ...
X_test_scaled = ...

# %% [markdown]
# ## 2) PCA

# %%
# TODO: fit PCA(n_components=2) on train and transform test
pca = ...
test_pca = ...
print("PCA shape:", test_pca.shape)

# %% [markdown]
# ## 3) t-SNE and UMAP

# %%
# TODO: run t-SNE and UMAP on test scaled matrix
# tsne = ...
# test_tsne = ...
# um = ...
# test_umap = ...

# %% [markdown]
# ## 4) Plot PCA

# %%
pca_df = pd.DataFrame({"x": test_pca[:,0], "y": test_pca[:,1]})
plt.figure(figsize=(7,5))
sns.scatterplot(data=pca_df, x="x", y="y", s=70)
plt.title("PCA on Test Set")
plt.tight_layout()
plt.show()
